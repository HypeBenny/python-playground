# %%
import pandas as pd

# %%
Dataset_dict = {
    'date':   ['2020-05-04', '2020-06-04', '20202-07-04'],
    'sale':   [34, 35, 36],
    'profit': [6, 7, 7],
    'QTY':    [2.3, 4.5, 5.7]
}

# %%
benny_df = pd.read_csv('C:\\Users\Acer\Downloads\kweku data.txt')

# %%
benny_df
# Out:
#      Game Number   Game Length  Unnamed: 2
# 0              1            30         NaN
# 1              2            29         NaN
# 2              3            31         NaN
# 3              4            16         NaN
# 4              5            24         NaN
# ..           ...           ...         ...
# 995          996            24         NaN
# 996          997            21         NaN
# 997          998            47         NaN
# 998          999            30         NaN
# 999         1000            12         NaN
#
# [1000 rows x 3 columns]

# %%
benny_df[' Game Length']
# Out:
# 0      30
# 1      29
# 2      31
# 3      16
# 4      24
#        ..
# 995    24
# 996    21
# 997    47
# 998    30
# 999    12
# Name:  Game Length, Length: 1000, dtype: int64

# %%
benny_df.describe()
# Out:
#        Game Number   Game Length  Unnamed: 2
# count  1000.000000   1000.000000         0.0
# mean    500.500000     35.411000         NaN
# std     288.819436     23.412608         NaN
# min       1.000000      7.000000         NaN
# 25%     250.750000     19.000000         NaN
# 50%     500.500000     30.000000         NaN
# 75%     750.250000     45.000000         NaN
# max    1000.000000    197.000000         NaN

# %%
benny_df.shape
# Out:
# (1000, 3)

# %%
benny_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Game Number   1000 non-null   int64
#  1    Game Length  1000 non-null   int64
#  2   Unnamed: 2    0 non-null      float64
# dtypes: float64(1), int64(2)
# memory usage: 23.6 KB

# %%
benny_df.loc[50:55]
# Out:
#     Game Number   Game Length  Unnamed: 2
# 50           51            56         NaN
# 51           52            20         NaN
# 52           53            47         NaN
# 53           54            51         NaN
# 54           55            22         NaN
# 55           56            46         NaN

# %%
benny_df[[' Game Length', 'Game Number']]
# Out:
#       Game Length  Game Number
# 0              30            1
# 1              29            2
# 2              31            3
# 3              16            4
# 4              24            5
# ..            ...          ...
# 995            24          996
# 996            21          997
# 997            47          998
# 998            30          999
# 999            12         1000
#
# [1000 rows x 2 columns]

# %%
benny_df['Game Number'][44]
# Out:
# 45

# %%
benny_df.at[44, 'Game Number']
# Out:
# 45

# %%
benny_df.tail(11)
# Out:
#      Game Number   Game Length  Unnamed: 2
# 989          990            25         NaN
# 990          991            24         NaN
# 991          992            27         NaN
# 992          993            28         NaN
# 993          994            32         NaN
# 994          995            93         NaN
# 995          996            24         NaN
# 996          997            21         NaN
# 997          998            47         NaN
# 998          999            30         NaN
# 999         1000            12         NaN

# %%
benny_df_copy = benny_df.copy()

# %%
benny_df[' Game Length'].sum()
# Out:
# 35411

# %%
high = benny_df[' Game Length'] > 25
high
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997     True
# 998     True
# 999    False
# Name:  Game Length, Length: 1000, dtype: bool

# %%
benny_df[high]
# Out:
#      Game Number   Game Length  Unnamed: 2
# 0              1            30         NaN
# 1              2            29         NaN
# 2              3            31         NaN
# 5              6            29         NaN
# 6              7            28         NaN
# ..           ...           ...         ...
# 992          993            28         NaN
# 993          994            32         NaN
# 994          995            93         NaN
# 997          998            47         NaN
# 998          999            30         NaN
#
# [590 rows x 3 columns]

# %%
glen = benny_df[' Game Length'] / 2
glen
# Out:
# 0      15.0
# 1      14.5
# 2      15.5
# 3       8.0
# 4      12.0
#        ...
# 995    12.0
# 996    10.5
# 997    23.5
# 998    15.0
# 999     6.0
# Name:  Game Length, Length: 1000, dtype: float64

# %%
benny_df['glen'] = glen
benny_df
# Out:
#      Game Number   Game Length  Unnamed: 2  glen
# 0              1            30         NaN  15.0
# 1              2            29         NaN  14.5
# 2              3            31         NaN  15.5
# 3              4            16         NaN   8.0
# 4              5            24         NaN  12.0
# ..           ...           ...         ...   ...
# 995          996            24         NaN  12.0
# 996          997            21         NaN  10.5
# 997          998            47         NaN  23.5
# 998          999            30         NaN  15.0
# 999         1000            12         NaN   6.0
#
# [1000 rows x 4 columns]

# %%
benny_df['high'] = high
benny_df
# Out:
#      Game Number   Game Length  Unnamed: 2  glen   high
# 0              1            30         NaN  15.0   True
# 1              2            29         NaN  14.5   True
# 2              3            31         NaN  15.5   True
# 3              4            16         NaN   8.0  False
# 4              5            24         NaN  12.0  False
# ..           ...           ...         ...   ...    ...
# 995          996            24         NaN  12.0  False
# 996          997            21         NaN  10.5  False
# 997          998            47         NaN  23.5   True
# 998          999            30         NaN  15.0   True
# 999         1000            12         NaN   6.0  False
#
# [1000 rows x 5 columns]

# %%
benny_df.drop(columns=['Unnamed: 2'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Acer\OneDrive\Desktop\intro to python\lessons\pandas1.ipynb Cell 21 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Acer/OneDrive/Desktop/intro%20to%20python/lessons/pandas1.ipynb#ch0000023?line=0'>1</a> benny_df.drop(columns=['Unnamed: 2'], inplace=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/Acer/OneDrive/Desktop/intro%20to%20python/lessons/pandas1.ipynb#ch0000023?line=1'>2</a> benny_df
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
# ...

# %%
benny_df
# Out:
#      Game Number   Game Length  glen   high
# 0              1            30  15.0   True
# 1              2            29  14.5   True
# 2              3            31  15.5   True
# 3              4            16   8.0  False
# 4              5            24  12.0  False
# ..           ...           ...   ...    ...
# 995          996            24  12.0  False
# 996          997            21  10.5  False
# 997          998            47  23.5   True
# 998          999            30  15.0   True
# 999         1000            12   6.0  False
#
# [1000 rows x 4 columns]

# %%
benny_df.drop(columns=['high'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Acer\OneDrive\Desktop\intro to python\lessons\pandas1.ipynb Cell 23 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Acer/OneDrive/Desktop/intro%20to%20python/lessons/pandas1.ipynb#ch0000025?line=0'>1</a> benny_df.drop('999')
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
import openpyxl

# %%
excel_file = 'benny sales data.xlsx'
kweku_df = pd.read_excel(excel_file, header=1)

# %%
kweku_df
# Out:
#      Unnamed: 0     Sales Person    Geography         Product  Amount  Units  \
# 0           NaN     Barr Faughny  New Zealand  50% Dark Bites    1057     54
# 1           NaN     Ches Bonnell    Australia  50% Dark Bites    1281     75
# 2           NaN     Ches Bonnell        India  50% Dark Bites    1932    369
# 3           NaN  Gunar Cockshoot          USA  50% Dark Bites    2415    255
# 4           NaN       Oby Sorrel          USA  50% Dark Bites    3472     96
# ..          ...              ...          ...             ...     ...    ...
# 295         NaN     Husein Augar  New Zealand      White Choc    4305    156
# 296         NaN       Ram Mahesh       Canada      White Choc    5439     30
# 297         NaN  Gunar Cockshoot        India      White Choc    6300     42
# 298         NaN     Gigi Bohling    Australia      White Choc    7483     45
# 299         NaN     Gigi Bohling  New Zealand      White Choc    8813     21
#
#      COST PER UNIT TOTAL COST  PROFIT
# ...

# %%
kweku_df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
kweku_df
# Out:
#         Sales Person    Geography         Product  Amount  Units  \
# 0       Barr Faughny  New Zealand  50% Dark Bites    1057     54
# 1       Ches Bonnell    Australia  50% Dark Bites    1281     75
# 2       Ches Bonnell        India  50% Dark Bites    1932    369
# 3    Gunar Cockshoot          USA  50% Dark Bites    2415    255
# 4         Oby Sorrel          USA  50% Dark Bites    3472     96
# ..               ...          ...             ...     ...    ...
# 295     Husein Augar  New Zealand      White Choc    4305    156
# 296       Ram Mahesh       Canada      White Choc    5439     30
# 297  Gunar Cockshoot        India      White Choc    6300     42
# 298     Gigi Bohling    Australia      White Choc    7483     45
# 299     Gigi Bohling  New Zealand      White Choc    8813     21
#
#      COST PER UNIT TOTAL COST  PROFIT
# 0            11.70        632     425
# 1            11.70        878     404
# 2            11.70       4317   -2385
# ...

# %%
kweku_df.sort_values('PROFIT', ascending=False).head(10)
# Out:
#      Sales Person    Geography               Product  Amount  Units  \
# 208  Gigi Bohling       Canada       Mint Chip Choco   16184     39
# 108  Husein Augar        India  Caramel Stuffed Bars   14329    150
# 249    Oby Sorrel           UK   Peanut Butter Cubes   12950     30
# 218  Gigi Bohling        India          Orange Choco   15610    339
# 207  Barr Faughny       Canada       Mint Chip Choco   11417     21
# 262  Gigi Bohling          USA       Raspberry Choco   13391    201
# 131  Barr Faughny  New Zealand         Drinking Coco   11571    138
# 120    Ram Mahesh          USA  Choco Coated Almonds   12348    234
# 119  Carla Molina       Canada  Choco Coated Almonds   10304     84
# 130   Brien Boise           UK         Drinking Coco    9660     27
#
#      COST PER UNIT TOTAL COST  PROFIT
# 208           8.79        343   15841
# 108          10.38       1557   12772
# 249          12.37        371   12579
# 218          10.62       3600   12010
# ...

# %%
kweku_df['Units'][208] = 65
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_16192\1895211338.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kweku_df['Units'][208] = 65

# %%
kweku_df['Units'][208]
# Out:
# 65

# %%
kweku_df.sort_values('PROFIT', ascending=False).head(10)
# Out:
#      Sales Person    Geography               Product  Amount  Units  \
# 208  Gigi Bohling       Canada       Mint Chip Choco   16184     65
# 108  Husein Augar        India  Caramel Stuffed Bars   14329    150
# 249    Oby Sorrel           UK   Peanut Butter Cubes   12950     30
# 218  Gigi Bohling        India          Orange Choco   15610    339
# 207  Barr Faughny       Canada       Mint Chip Choco   11417     21
# 262  Gigi Bohling          USA       Raspberry Choco   13391    201
# 131  Barr Faughny  New Zealand         Drinking Coco   11571    138
# 120    Ram Mahesh          USA  Choco Coated Almonds   12348    234
# 119  Carla Molina       Canada  Choco Coated Almonds   10304     84
# 130   Brien Boise           UK         Drinking Coco    9660     27
#
#      COST PER UNIT TOTAL COST  PROFIT
# 208           8.79        343   15841
# 108          10.38       1557   12772
# 249          12.37        371   12579
# 218          10.62       3600   12010
# ...

# %%
kweku_df['Units'][208] = 39
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_16192\4182109075.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kweku_df['Units'][208] = 39

# %%
kweku_df.sort_values('PROFIT', ascending=False).head(10)
# Out:
#      Sales Person    Geography               Product  Amount  Units  \
# 208  Gigi Bohling       Canada       Mint Chip Choco   16184     39
# 108  Husein Augar        India  Caramel Stuffed Bars   14329    150
# 249    Oby Sorrel           UK   Peanut Butter Cubes   12950     30
# 218  Gigi Bohling        India          Orange Choco   15610    339
# 207  Barr Faughny       Canada       Mint Chip Choco   11417     21
# 262  Gigi Bohling          USA       Raspberry Choco   13391    201
# 131  Barr Faughny  New Zealand         Drinking Coco   11571    138
# 120    Ram Mahesh          USA  Choco Coated Almonds   12348    234
# 119  Carla Molina       Canada  Choco Coated Almonds   10304     84
# 130   Brien Boise           UK         Drinking Coco    9660     27
#
#      COST PER UNIT TOTAL COST  PROFIT
# 208           8.79        343   15841
# 108          10.38       1557   12772
# 249          12.37        371   12579
# 218          10.62       3600   12010
# ...

# %%
kweku_df[['PROFIT', 'Units', 'Amount']].sum()
# Out:
# PROFIT     801165
# Units       45660
# Amount    1240869
# dtype: int64

# %%
kweku_df[kweku_df['Sales Person'] == 'Carla Molina']
# Out:
#      Sales Person    Geography               Product  Amount  Units  \
# 5    Carla Molina           UK        50% Dark Bites    3976     72
# 13   Carla Molina  New Zealand        70% Dark Bites    1526    240
# 21   Carla Molina       Canada        70% Dark Bites    6118    174
# 34   Carla Molina  New Zealand         85% Dark Bars    6398    102
# 38   Carla Molina          USA       99% Dark & Pure     609     99
# 42   Carla Molina       Canada       99% Dark & Pure    1925    192
# 51   Carla Molina        India           After Nines     336    144
# 60   Carla Molina    Australia           After Nines    5915      3
# 77   Carla Molina       Canada   Baker's Choco Chips      98    204
# 81   Carla Molina  New Zealand   Baker's Choco Chips    2324    177
# 94   Carla Molina       Canada  Caramel Stuffed Bars     854    309
# 107  Carla Molina          USA  Caramel Stuffed Bars    7455    216
# 119  Carla Molina       Canada  Choco Coated Almonds   10304     84
# ...

# %%
result_df = kweku_df[['Product', 'PROFIT', 'Units', 'Amount']]

# %%
result_df
# Out:
#             Product  PROFIT  Units  Amount
# 0    50% Dark Bites     425     54    1057
# 1    50% Dark Bites     404     75    1281
# 2    50% Dark Bites   -2385    369    1932
# 3    50% Dark Bites    -569    255    2415
# 4    50% Dark Bites    2349     96    3472
# ..              ...     ...    ...     ...
# 295      White Choc    2254    156    4305
# 296      White Choc    5045     30    5439
# 297      White Choc    5748     42    6300
# 298      White Choc    6891     45    7483
# 299      White Choc    8537     21    8813
#
# [300 rows x 4 columns]

# %%
result_df.to_excel('woop.xlsx', index=False)

# %%
kweku_df['Amount'].plot(title='ya gye sika',)
# Out:
# <AxesSubplot:title={'center':'ya gye sika'}>
